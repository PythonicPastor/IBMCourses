# %%
# %matplotlib ipympl
import pandas as pd
import matplotlib.pyplot as plt

# %%
#plt.plot(5,5,'o')

# %%
df = pd.read_csv('Census.csv')
df
# Out:
#    COMMUNITY_AREA_NAME  PERCENT_AGED_16__UNEMPLOYED  PER_CAPITA_INCOME  \
# 0          Rogers Park                          8.7              23939
# 1           West Ridge                          8.8              23040
# 2               Uptown                          8.9              35787
# 3       Lincoln Square                          8.2              37524
# 4         North Center                          5.2              57123
# ..                 ...                          ...                ...
# 73     Mount Greenwood                          8.7              34381
# 74         Morgan Park                         15.0              27149
# 75              O'Hare                          7.1              25828
# 76           Edgewater                          9.2              33385
# 77             CHICAGO                         12.9              28202
#
#     HARDSHIP_INDEX
# 0             39.0
# 1             46.0
# 2             20.0
# 3             17.0
# ...

# %%
df['PER_CAPITA_INCOME'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
