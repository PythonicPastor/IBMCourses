# %%
# Import required libraries
import pandas as pd
import plotly.graph_objects as go
import dash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output

# Read the airline data into pandas dataframe
airline_data =  pd.read_csv('airline_data.csv')
airline_data
# Out:
# C:\Users\simpl\AppData\Local\Temp\ipykernel_12624\1373718610.py:5: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html
# C:\Users\simpl\AppData\Local\Temp\ipykernel_12624\1373718610.py:6: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   import dash_core_components as dcc
#        Unnamed: 0  Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0         1295781  1998        2      4           2          4  1998-04-02
# 1         1125375  2013        2      5          13          1  2013-05-13
# 2          118824  1993        3      9          25          6  1993-09-25
# 3          634825  1994        4     11          12          6  1994-11-12
# 4         1888125  2017        3      8          17          4  2017-08-17
# ...           ...   ...      ...    ...         ...        ...         ...
# 26995      821542  2017        1      1          24          2  2017-01-24
# 26996     1910565  2013        2      6          27          4  2013-06-27
# 26997        9055  2016        3      8          26          5  2016-08-26
# 26998       84136  2009        3      8           8          6  2009-08-08
# 26999      113029  1993        3      7          17          6  1993-07-17
#
#       Reporting_Airline  DOT_ID_Reporting_Airline IATA_CODE_Reporting_Airline  \
# 0                    AS                     19930                          AS
# 1                    EV                     20366                          EV
# 2                    UA                     19977                          UA
# 3                    HP                     19991                          HP
# 4                    UA                     19977                          UA
# ...                 ...                       ...                         ...
# 26995                DL                     19790                          DL
# 26996                B6                     20409                          B6
# 26997                AA                     19805                          AA
# 26998                YV                     20378                          YV
# 26999                DL                     19790                          DL
#
#        ... Div4WheelsOff  Div4TailNum  Div5Airport  Div5AirportID  \
# 0      ...           NaN          NaN          NaN            NaN
# 1      ...           NaN          NaN          NaN            NaN
# 2      ...           NaN          NaN          NaN            NaN
# 3      ...           NaN          NaN          NaN            NaN
# 4      ...           NaN          NaN          NaN            NaN
# ...    ...           ...          ...          ...            ...
# 26995  ...           NaN          NaN          NaN            NaN
# 26996  ...           NaN          NaN          NaN            NaN
# 26997  ...           NaN          NaN          NaN            NaN
# 26998  ...           NaN          NaN          NaN            NaN
# 26999  ...           NaN          NaN          NaN            NaN
#
#        Div5AirportSeqID Div5WheelsOn Div5TotalGTime Div5LongestGTime  \
# 0                   NaN          NaN            NaN              NaN
# 1                   NaN          NaN            NaN              NaN
# 2                   NaN          NaN            NaN              NaN
# 3                   NaN          NaN            NaN              NaN
# 4                   NaN          NaN            NaN              NaN
# ...                 ...          ...            ...              ...
# 26995               NaN          NaN            NaN              NaN
# 26996               NaN          NaN            NaN              NaN
# 26997               NaN          NaN            NaN              NaN
# 26998               NaN          NaN            NaN              NaN
# 26999               NaN          NaN            NaN              NaN
#
#        Div5WheelsOff Div5TailNum
# 0                NaN         NaN
# 1                NaN         NaN
# 2                NaN         NaN
# 3                NaN         NaN
# 4                NaN         NaN
# ...              ...         ...
# 26995            NaN         NaN
# 26996            NaN         NaN
# 26997            NaN         NaN
# 26998            NaN         NaN
# 26999            NaN         NaN
#
# [27000 rows x 110 columns]

# %%
# Create a dash application
app = dash.Dash(__name__)

# Get the layout of the application and adjust it.
# Create an outer division using html.Div and add title to the dashboard using html.H1 component
# Add a html.Div and core input text component
# Finally, add graph component.
app.layout = html.Div(children=[html.H1('Airline Performance Dashboard',
                                       style={'textAlign' : 'center',
                                             'color':'#503D36',
                                             'font-size':40
                                             }),                                
                                html.Div(["Input Year", 
                                          dcc.Input(id='input-year',
                                                    type='number',
                                                    value='2010',
                                                    style={'font-size':35})
                                         ]),
                                html.Br(),
                                html.Br(),
                                html.Div(dcc.Graph(id='line-plot')),
                                ])
# add callback decorator
@app.callback(Output(component_id='line-plot', component_property='figure'),
               Input(component_id='input-year', component_property='value'))

# Add computation to callback function and return graph
def get_graph(entered_year):
    # Select data based on the entered year
    df =  airline_data[airline_data['Year']==int(entered_year)]
    
    # Group the data by Month and compute average over arrival delay time.
    line_data = df.groupby('Month')['ArrDelay'].mean().reset_index()
    
    # 
    fig = go.Figure(data=go.Scatter(x=line_data['Month'],
                                     y=line_data.ArrDelay,
                                     mode='lines',
                                     marker=dict(color='green')))
    fig.update_layout(title="Month vs Average Flight Delay Time",
                     xaxis_title="Month",
                     yaxis_title="ArrDelay")
    return fig

# Run the app
if __name__ == '__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:8050
# Press CTRL+C to quit
# 127.0.0.1 - - [16/Aug/2022 07:30:32] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:30:32] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:30:32] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:30:32] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 304 -
# 127.0.0.1 - - [16/Aug/2022 07:30:32] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 304 -
# 127.0.0.1 - - [16/Aug/2022 07:30:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:10] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:10] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:10] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:10] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:10] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:10] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:14] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:14] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:14] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:14] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:20] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:22] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:52] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:52] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:52] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2022 07:31:52] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 304 -
# 127.0.0.1 - - [16/Aug/2022 07:31:52] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 304 -
# 127.0.0.1 - - [16/Aug/2022 07:31:52] "POST /_dash-update-component HTTP/1.1" 200 -
